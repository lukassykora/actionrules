# %% [markdown]
# # Titanic - Action Rules Discovery
#
# Action rules provide the key to making the right actions that improve the
# system to more objects have the desired target (reclassify them).
#
# Based on the Titanic dataset („Titanic: Machine Learning from Disaster“, 2012),
# we could get information about what people could do to raise their probability of survival.
#
# ## Installation of the package
#
# The source code is available in https://github.com/lukassykora/actionrules.
# The package was uploaded to PyPi (Python Package Index). The page of the project is
# https://test.pypi.org/project/actionrules-lukassykora/.
# The easiest way for installation is:
#
# **pip install -i https://test.pypi.org/simple/ actionrules-lukassykora**
#
# ## How to run it?
#
# Firstly the module must be imported.

# %%
from actionrules.actionRulesDiscovery import ActionRulesDiscovery
import pandas as pd

# %% [markdown]
# ### Instantiate model object and load data
#
# All columns should be nominal data.

# %%
dataFrame = pd.read_csv("data/titanic.csv", sep=";")
actionRulesDiscovery = ActionRulesDiscovery()
actionRulesDiscovery.load_pandas(dataFrame)
dataFrame.head()
# Out:
#    ID                  Age Embarked       Fare  Pclass     Sex  Survived
# 0   1  <16.13336;32.10002)        S  very high     1.0  female       1.0
# 1   2    <0.1667;16.13336)        S  very high     1.0    male       1.0
# 2   3    <0.1667;16.13336)        S  very high     1.0  female       0.0
# 3   4  <16.13336;32.10002)        S  very high     1.0    male       0.0
# 4   5  <16.13336;32.10002)        S  very high     1.0  female       0.0

# %% [markdown]
# ### Fit  - parameters
#
# For mining from source dataset the method **fit** can be used. In this case library PyFIM is
# used for classification rules discovery. The function has the parameters below:

# %%
help(actionRulesDiscovery.fit)
# Out:
# Help on method fit in module actionrules.actionRulesDiscovery.actionRulesDiscovery:
#
# fit(stable_antecedents:List[str], flexible_antecedents:List[str], consequent:str, conf:float, supp:float, desired_classes:List[str]=None, desired_changes:List[list]=None, is_nan:bool=False, is_reduction:bool=True, min_stable_antecedents:int=1, min_flexible_antecedents:int=1, max_stable_antecedents:int=5, max_flexible_antecedents:int=5) method of actionrules.actionRulesDiscovery.actionRulesDiscovery.ActionRulesDiscovery instance
#     Get action rules.
#     Define antecedent and consequent.
#     - stable_antecedents - List of column names.
#     - flexible_antecedents - List of column names.
#     - consequent - Name of the consequent column.
#     Confidence and support.
#     - conf - Value in % for minimal confidence in classification rules.
#              For example, 60.
#     - supp - Value in % for minimal support of classification rules.
#              For example, 5.
#     Desired classes or desired changes must be entered.
#     - desired_classes - List of decision states. For example, ["1"].
#                         DEFAULT: None
#     - desired_changes - List of desired changes. For example, [["0", "1"]].
#                         DEFAULT: None
#     Should NaN values be used?
#     - is_nan - True means NaN values are used, False means NaN values are not used.
#                DEFAULT: FALSE
#     Should the reduction table be used?
#     - is_reduction - Is the reduction table used? DEFAULT: TRUE
#     Minimal number of stable and flexible couples
#     - min_stable_antecedents - Minimal number of stable antecedents. DEFAULT: 1
#     - min_flexible_antecedents - Minimal number of flexible couples. DEFAULT: 1
#     - max_stable_antecedents - Maximal number of stable antecedents. DEFAULT: 5
#     - max_flexible_antecedents - Maximal number of flexible couples. DEFAULT: 5

# %% [markdown]
# ### Fit model to training data
#
# The action rules are discovered from classification rules that have min. confidence 55% and min. support 3%.
#
# Stable part of action rule is "Age". Stable antecedents do not allow any change of their state (no action can be taken).
#
# Flexible attributes are "Embarked", "Fare", "Pclass". Flexible attributes allow changing their state (the action can be taken). The main task of this algorithm is to find these actions.
#
# Target is a Survived value 1.0.

# %%
actionRulesDiscovery.fit(stable_antecedents = ["Age", "Sex"],
            flexible_antecedents = ["Embarked", "Fare", "Pclass"],
            consequent = "Survived",
            conf=55,
            supp=3,
            desired_classes = ["1.0"],
            is_reduction = True,
)

# %% [markdown]
# ### Number of discovered action rules

# %%
len(actionRulesDiscovery.get_pretty_action_rules())
# Out:
# 13

# %% [markdown]
# ### Representation of action rules

# %%
for rule in actionRulesDiscovery.get_action_rules_representation():
    print(rule)
    print(" ")
# Out:
# r = [(Sex: female) ∧ (Embarked: S → C)  ∧ (Pclass: 3.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.05267175572519084 and confidence: 0.5876187356698329
#
# r = [(Age: <16.13336;32.10002)) ∧ (Embarked: S → C) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.04198473282442748 and confidence: 0.40990990990991
#
# r = [(Age: <16.13336;32.10002)) ∧ (Pclass: 3.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.04732824427480916 and confidence: 0.5261127825349071
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: avg → very high) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.044274809160305344 and confidence: 0.43256997455470736
#
# r = [(Age: <16.13336;32.10002)) ∧ (Pclass: 2.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.04732824427480916 and confidence: 0.42040850078557845
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: avg → very high)  ∧ (Pclass: 2.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.03969465648854962 and confidence: 0.46254681647940077
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: very low → very high) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.044274809160305344 and confidence: 0.4610591900311526
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: very low → very high)  ∧ (Pclass: 3.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.03969465648854962 and confidence: 0.49948078920041533
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: lower → very high) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.044274809160305344 and confidence: 0.5373134328358209
#
# r = [(Age: <16.13336;32.10002)) ∧ (Fare: lower → very high)  ∧ (Pclass: 3.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.03969465648854962 and confidence: 0.582089552238806
#
# r = [(Age: <32.10002;48.06668)) ∧ (Pclass: 3.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.05114503816793893 and confidence: 0.5283294392523364
#
# r = [(Age: <32.10002;48.06668)) ∧ (Pclass: 2.0 → 1.0) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.031297709923664124 and confidence: 0.3889832908524497
#
# r = [(Age: <32.10002;48.06668)) ∧ (Fare: higher → very high) ] ⇒ [Survived: 0.0 → 1.0] with support: 0.031297709923664124 and confidence: 0.42607843137254897

# %% [markdown]
# ### Text representation of action rules

# %%
for pretty_rule in actionRulesDiscovery.get_pretty_action_rules():
    print(pretty_rule)
    print(" ")
# Out:
# If attribute 'Sex' is 'female', attribute 'Embarked' value 'S' is changed to 'C', attribute 'Pclass' value '3.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.05267175572519084 and confidence: 0.5876187356698329.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Embarked' value 'S' is changed to 'C', then 'Survived' value '0.0' is changed to '1.0' with support: 0.04198473282442748 and confidence: 0.40990990990991.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Pclass' value '3.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.04732824427480916 and confidence: 0.5261127825349071.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'avg' is changed to 'very high', then 'Survived' value '0.0' is changed to '1.0' with support: 0.044274809160305344 and confidence: 0.43256997455470736.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Pclass' value '2.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.04732824427480916 and confidence: 0.42040850078557845.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'avg' is changed to 'very high', attribute 'Pclass' value '2.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.03969465648854962 and confidence: 0.46254681647940077.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'very low' is changed to 'very high', then 'Survived' value '0.0' is changed to '1.0' with support: 0.044274809160305344 and confidence: 0.4610591900311526.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'very low' is changed to 'very high', attribute 'Pclass' value '3.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.03969465648854962 and confidence: 0.49948078920041533.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'lower' is changed to 'very high', then 'Survived' value '0.0' is changed to '1.0' with support: 0.044274809160305344 and confidence: 0.5373134328358209.
#
# If attribute 'Age' is '<16.13336;32.10002)', attribute 'Fare' value 'lower' is changed to 'very high', attribute 'Pclass' value '3.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.03969465648854962 and confidence: 0.582089552238806.
#
# If attribute 'Age' is '<32.10002;48.06668)', attribute 'Pclass' value '3.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.05114503816793893 and confidence: 0.5283294392523364.
#
# If attribute 'Age' is '<32.10002;48.06668)', attribute 'Pclass' value '2.0' is changed to '1.0', then 'Survived' value '0.0' is changed to '1.0' with support: 0.031297709923664124 and confidence: 0.3889832908524497.
#
# If attribute 'Age' is '<32.10002;48.06668)', attribute 'Fare' value 'higher' is changed to 'very high', then 'Survived' value '0.0' is changed to '1.0' with support: 0.031297709923664124 and confidence: 0.42607843137254897.

# %% [markdown]
# ### Human language
#
# To say the first rule in even more human language:
#
# **Women** who traveled from **Southampton** in the **third class** would increase their chance for survival if they would change their boarding place to **Cherbourg** and paid extra money for **first class**.

# %% [markdown]
# ### First action rule - before
# If you would like to see data that creates the first rule, you can use the following code. All these rows are the right candidate for reclassification.
#
# - Yellow background - stable attributes
#
# - Green background - flexible attributes
#
# - Red text - Target value

# %%
actionRulesDiscovery.get_source_data_for_ar(0, True)
# Out:
# <style  type="text/css" >
#     #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow0_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow1_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow2_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow3_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow4_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow5_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow6_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow7_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow8_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow9_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow10_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow11_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col2 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col3 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col4 {
#             background-color:  green;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col5 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow12_col6 {
#             color:  red;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f0bderow13_col1 {
#             background-color:  yellow;
#         }    #T_834dc106_13cc_11ea_846c_b808cf5f

# %% [markdown]
# ### First action rule - after
# In current data, you can see that if you reclassify the data, the chance of survival is higher.
#
# - Yellow background - stable attributes
#
# - Green background - flexible attributes
#
# - Red text - Target value

# %%
actionRulesDiscovery.get_source_data_for_ar(0, False)
# Out:
# <style  type="text/css" >
#     #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow0_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow1_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow2_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow3_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow4_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow5_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow6_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow7_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow8_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow9_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow10_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow11_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col2 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col3 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col4 {
#             background-color:  green;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col5 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow12_col6 {
#             color:  red;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f0bderow13_col1 {
#             background-color:  yellow;
#         }    #T_83b05376_13cc_11ea_a41c_b808cf5f

# %% [markdown]
# ### Prediction
# To predict new data, the method "predict" can be used. It creates new columns with recommended values.
#
# You can see below that for the data, two action rules were found (the number in the header after the text "recommended" is the number of action rule). The action rule 0 wants to change Embarked from S to C, and both rules (n. 0 and n. 10) want to Pclass from 3.0 to 1.0.

# %%
new_data = [['<32.10002;48.06668)','female', 'S', 'very high' ,'3.0']] 
df_new_data = pd.DataFrame(new_data, columns = ["Age", "Sex", "Embarked", "Fare", "Pclass"]) 

actionRulesDiscovery.predict(df_new_data)
# Out:
#                    Age Embarked Embarked-recommended-0       Fare Pclass  \
# 0  <32.10002;48.06668)        S                      C  very high    3.0
# 0  <32.10002;48.06668)        S                    NaN  very high    3.0
#
#   Pclass-recommended-0 Pclass-recommended-10     Sex
# 0                  1.0                   NaN  female
# 0                  NaN                   1.0  female

# %% [markdown]
# ### Machine representation

# %%
actionRulesDiscovery.get_action_rules()
# Out:
# [[[[['Sex', ('female',)]],
#    [['Embarked', ('S', 'C')], ['Pclass', ('3.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.059541984732824425, 0.05267175572519084, 0.05267175572519084],
#   [0.6046511627906976, 0.971830985915493, 0.5876187356698329]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Embarked', ('S', 'C')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.2083969465648855, 0.04198473282442748, 0.04198473282442748],
#   [0.6707616707616708, 0.6111111111111112, 0.40990990990991]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Pclass', ('3.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.16793893129770993, 0.04732824427480916, 0.04732824427480916],
#   [0.738255033557047, 0.7126436781609196, 0.5261127825349071]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('avg', 'very high')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.0648854961832061, 0.044274809160305344, 0.044274809160305344],
#   [0.648854961832061, 0.6666666666666666, 0.43256997455470736]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Pclass', ('2.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.06259541984732825, 0.04732824427480916, 0.04732824427480916],
#   [0.5899280575539568, 0.7126436781609196, 0.42040850078557845]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('avg', 'very high')], ['Pclass', ('2.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.04351145038167939, 0.03969465648854962, 0.03969465648854962],
#   [0.6404494382022472, 0.7222222222222222, 0.46254681647940077]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('very low', 'very high')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.05648854961832061, 0.044274809160305344, 0.044274809160305344],
#   [0.6915887850467289, 0.6666666666666666, 0.4610591900311526]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('very low', 'very high')], ['Pclass', ('3.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.05648854961832061, 0.03969465648854962, 0.03969465648854962],
#   [0.6915887850467289, 0.7222222222222222, 0.49948078920041533]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('lower', 'very high')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.08244274809160305, 0.044274809160305344, 0.044274809160305344],
#   [0.8059701492537313, 0.6666666666666666, 0.5373134328358209]],
#  [[[['Age', ('<16.13336;32.10002)',)]],
#    [['Fare', ('lower', 'very high')], ['Pclass', ('3.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.08244274809160305, 0.03969465648854962, 0.03969465648854962],
#   [0.8059701492537313, 0.7222222222222222, 0.582089552238806]],
#  [[[['Age', ('<32.10002;48.06668)',)]],
#    [['Pclass', ('3.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.06183206106870229, 0.05114503816793893, 0.05114503816793893],
#   [0.84375, 0.6261682242990654, 0.5283294392523364]],
#  [[[['Age', ('<32.10002;48.06668)',)]],
#    [['Pclass', ('2.0', '1.0')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.031297709923664124, 0.05114503816793893, 0.031297709923664124],
#   [0.6212121212121212, 0.6261682242990654, 0.3889832908524497]],
#  [[[['Age', ('<32.10002;48.06668)',)]],
#    [['Fare', ('higher', 'very high')]],
#    ['Survived', ['0.0', '1.0']]],
#   [0.031297709923664124, 0.04045801526717557, 0.031297709923664124],
#   [0.6029411764705882, 0.7066666666666667, 0.42607843137254897]]]
